# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviojoele/Alura/blob/main/introdu_o_a_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Notas = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv')
Notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
Notas.shape
# Out:
# (100836, 4)

# %%
Notas.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
Notas.columns = ["UsuarioID", "FilmeID", "Nota", "Momento"]
Notas
# Out:
#         UsuarioID  FilmeID  Nota     Momento
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
Notas.head()
# Out:
#    UsuarioID  FilmeID  Nota    Momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
Notas['Nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: Nota, Length: 100836, dtype: float64

# %%
Notas['Nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
Notas['Nota'].value_counts()
# Out:
# Nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
Notas['Nota'].mean()
# Out:
# 3.501556983616962
